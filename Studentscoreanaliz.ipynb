# %% [markdown]
# <a href="https://colab.research.google.com/github/fidanismayilzada23/Data-Analitc/blob/main/Studentscoreanaliz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
df.shape
# Out:
# (1000, 8)

# %%
#ümumi melumatları.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
#setir sayı
len(df)
# Out:
# 1000

# %%
#null deyerlerin sayı
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
#duplikat deyerlerin sayı
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df['total score']=df['math score']+df['reading score']+df['writing score']

# %%
df['average score']=(df['total score']/3).round()

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total score                                      Average score  \
# 0          218  <bound method Series.round of 0      72.666667...
# 1          247  <bound method Series.round of 0      72.666667...
# 2          278  <bound method Series.round of 0      72.666667...
# 3          148  <bound method Series.round of 0      72.666667...
# 4          229  <bound method Series.round of 0      72.666667...
#
#    average score
# 0           73.0
# 1           82.0
# 2           93.0
# 3           49.0
# 4           76.0

# %%
df.describe()
# Out:
#        math score  reading score  writing score  total score  average score
# count  1000.00000    1000.000000    1000.000000  1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000   203.312000      67.762000
# std      15.16308      14.600192      15.195657    42.771978      14.258354
# min       0.00000      17.000000      10.000000    27.000000       9.000000
# 25%      57.00000      59.000000      57.750000   175.000000      58.000000
# 50%      66.00000      70.000000      69.000000   205.000000      68.000000
# 75%      77.00000      79.000000      79.000000   233.000000      78.000000
# max     100.00000     100.000000     100.000000   300.000000     100.000000

# %%
df.describe(include='O')  #Object
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
#
#        test preparation course  \
# count                     1000
# unique                       2
# top                       none
# freq                       642
#
#                                             Average score
# count                                                1000
# unique                                                  1
# top     <bound method Series.round of 0      72.666667...
# freq                                                 1000

# %%
df.nunique()  #unik deyerlerin sayı
# Out:
# gender                           2
# race/ethnicity                   5
# parental level of education      6
# lunch                            2
# test preparation course          2
# math score                      81
# reading score                   72
# writing score                   77
# total score                    194
# Average score                    1
# average score                   73
# dtype: int64

# %%
#Ortalaması 50 den yuxarı olanlar imtahandan keçdi.
df['resualt']=(df['average score']>50).astype(int)
df['resualt']
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 995    1
# 996    1
# 997    1
# 998    1
# 999    1
# Name: resualt, Length: 1000, dtype: int64

# %%
#qruplaşdırıb sayır neçe nefer keçib neçe nefer qalıb
df['resualt'].value_counts().reset_index()
# Out:
#    resualt  count
# 0        1    883
# 1        0    117

# %%
#aralarındakı elaqeleri gösterir
df.corr(numeric_only=True)
# Out:
#                math score  reading score  writing score  total score  \
# math score       1.000000       0.817580       0.802642     0.918746
# reading score    0.817580       1.000000       0.954598     0.970331
# writing score    0.802642       0.954598       1.000000     0.965667
# total score      0.918746       0.970331       0.965667     1.000000
# average score    0.918442       0.970143       0.965643     0.999820
# resualt          0.578166       0.613112       0.612141     0.631727
#
#                average score   resualt
# math score          0.918442  0.578166
# reading score       0.970143  0.613112
# writing score       0.965643  0.612141
# total score         0.999820  0.631727
# average score       1.000000  0.632261
# resualt             0.632261  1.000000

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'total score', 'Average score', 'average score',
#        'resualt'],
#       dtype='object')

# %%
#her qrupun paylanmasını gösterir bu şekilde
for col in ['gender','race/ethnicity','parental level of education','lunch','test preparation course']:
  print(df[col].value_counts())
print()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64
# test preparation course
# none         642
# completed    358
# Name: count, dtype: int64

# %%
df.groupby('gender')[['math score','reading score','writing score']].mean().reset_index()
# Out:
#    gender  math score  reading score  writing score
# 0  female   63.633205      72.608108      72.467181
# 1    male   68.728216      65.473029      63.311203

# %%
for col in ['lunch','test prepation course']:
  print(df.groupby('gender')[['math score','reading score','writing score']].mean())
  print()
# Out:
#         math score  reading score  writing score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203
#
#         math score  reading score  writing score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
reading_full=(df['reading score']==100).sum()
math_full=(df['math score']==100).sum()
writing_full=(df['writing score']==100).sum()
print(f'Readingden full alanların sayı:{reading_full}')
print(f'Mathden full alanların sayı:{math_full}')
print(f'Writingden full alanların sayı:{writing_full}')
# Out:
# Readingden full alanların sayı:17
# Mathden full alanların sayı:7
# Writingden full alanların sayı:14

# %%
reading_full=(df['reading score']<20).sum()
math_full=(df['math score']<20).sum()
writing_full=(df['writing score']<20).sum()
print(f'Readingden 20 den aşağı alanların sayı:{reading_full}')
print(f'Mathden 20 den aşağı sayı:{math_full}')
print(f'Writingden 20 den aşağı sayı:{writing_full}')
# Out:
# Readingden 20 den aşağı alanların sayı:1
# Mathden 20 den aşağı sayı:4
# Writingden 20 den aşağı sayı:3

# %%
df['average score'].mean()
# Out:
# np.float64(67.762)

# %%
high_avg=df[df['average score']>df['average score'].mean()].groupby('parental level of education').size().reset_index().rename(columns={0:'count'})
high_avg
# Out:
#   parental level of education  count
# 0          associate's degree    128
# 1           bachelor's degree     76
# 2                 high school     81
# 3             master's degree     39
# 4                some college    123
# 5            some high school     86
