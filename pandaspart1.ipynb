# %% [markdown]
# <a href="https://colab.research.google.com/github/fidanismayilzada23/Data-Analitc/blob/main/pandaspart1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
masinlar=pd.Series(['BMW','TOYOTA','TESLA'])
masinlar
# Out:
# 0       BMW
# 1    TOYOTA
# 2     TESLA
# dtype: object

# %%
masinlar.values
# Out:
# array(['BMW', 'TOYOTA', 'TESLA'], dtype=object)

# %%
masinlar.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
masinlar=pd.Series(['BMW','TOYOTA','TESLA'],index=['a','b','c'])
masinlar
# Out:
# a       BMW
# b    TOYOTA
# c     TESLA
# dtype: object

# %%
masinlar.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
bal={'Bayram':98,'Mehman':68,'Nazlı':70}
a=pd.Series(bal)
a
# Out:
# Bayram    98
# Mehman    68
# Nazlı     70
# dtype: int64

# %%
a['Mehman']
# Out:
# np.int64(68)

# %%
a>80
# Out:
# Bayram     True
# Mehman    False
# Nazlı     False
# dtype: bool

# %%
a[a>80]
# Out:
# Bayram    98
# dtype: int64

# %%
a['Bayram']=80
a
# Out:
# Bayram    80
# Mehman    68
# Nazlı     70
# dtype: int64

# %%
'Nazlı' in a
# Out:
# True

# %%
a/10
# Out:
# Bayram    8.0
# Mehman    6.8
# Nazlı     7.0
# dtype: float64

# %%
a.isnull()
# Out:
# Bayram    False
# Mehman    False
# Nazlı     False
# dtype: bool

# %%
a.isnull().sum() #nulların saını qaytarır isna da var hemçinin
# Out:
# np.int64(0)

# %%
#ctrl+m ile aşağıdakı kimi yazır # ile at qarşısına

# %% [markdown]
# #DATAFrame

# %%
mar=pd.Series(['BMW','TESLA','TOYOTA'])
reng=pd.Series(['qara','ağ','boz'])

# %%
masinlar=pd.DataFrame({'Marka':mar,'Reng':reng})
masinlar
# Out:
#     Marka  Reng
# 0     BMW  qara
# 1   TESLA    ağ
# 2  TOYOTA   boz

# %%
data={'Ad':['Bayram','Maryam','Sevinc','Teymur','Jasmin','Kamal','Emil'],
      'Cins': ['K','Q','Q','K','Q','K','K'],
      'Bal': [67,89,69,54,45,89,78]}
df=pd.DataFrame(data)
df
# Out:
#        Ad Cins  Bal
# 0  Bayram    K   67
# 1  Maryam    Q   89
# 2  Sevinc    Q   69
# 3  Teymur    K   54
# 4  Jasmin    Q   45
# 5   Kamal    K   89
# 6    Emil    K   78

# %%
df.head() #ilk 5 setire baxmaq istediyimizde
# Out:
#        Ad Cins  Bal
# 0  Bayram    K   67
# 1  Maryam    Q   89
# 2  Sevinc    Q   69
# 3  Teymur    K   54
# 4  Jasmin    Q   45

# %%
df.tail() #5 setir sonu gösterir buda
# Out:
#        Ad Cins  Bal
# 2  Sevinc    Q   69
# 3  Teymur    K   54
# 4  Jasmin    Q   45
# 5   Kamal    K   89
# 6    Emil    K   78

# %%
df['yas']=18

# %%
df.sample(3) # random bilgileri getiri içine neçe yazsaq o qeder getirir
# Out:
#        Ad Cins  Bal  yas
# 0  Bayram    K   67   18
# 5   Kamal    K   89   18
# 6    Emil    K   78   18

# %%
df=pd.DataFrame(data,columns=['Ad','Cins','Bal','Yas'])
df
# Out:
#        Ad Cins  Bal  Yas
# 0  Bayram    K   67  NaN
# 1  Maryam    Q   89  NaN
# 2  Sevinc    Q   69  NaN
# 3  Teymur    K   54  NaN
# 4  Jasmin    Q   45  NaN
# 5   Kamal    K   89  NaN
# 6    Emil    K   78  NaN

# %%
df['Yas']=18
df
# Out:
#        Ad Cins  Bal  Yas
# 0  Bayram    K   67   18
# 1  Maryam    Q   89   18
# 2  Sevinc    Q   69   18
# 3  Teymur    K   54   18
# 4  Jasmin    Q   45   18
# 5   Kamal    K   89   18
# 6    Emil    K   78   18

# %%
df['Status'] ='Telebe'
df
# Out:
#        Ad Cins  Bal  Yas  Status
# 0  Bayram    K   67   18  Telebe
# 1  Maryam    Q   89   18  Telebe
# 2  Sevinc    Q   69   18  Telebe
# 3  Teymur    K   54   18  Telebe
# 4  Jasmin    Q   45   18  Telebe
# 5   Kamal    K   89   18  Telebe
# 6    Emil    K   78   18  Telebe

# %%
df.iloc[2] #2 ci setirin melumatlarını series şeklinde qaytarır
# Out:
# Ad        Sevinc
# Cins           Q
# Bal           69
# Yas           18
# Status    Telebe
# Name: 2, dtype: object

# %%
df.iloc[2,[2,3]]
# Out:
# Bal    69
# Yas    18
# Name: 2, dtype: object

# %%
df.loc[2,['Bal']] #loc sütün adlari ile çağira bilirik
# Out:
# Bal    69
# Name: 2, dtype: object

# %%
df.loc[[2,5],['Ad','Yas']]
# Out:
#        Ad  Yas
# 2  Sevinc   18
# 5   Kamal   18

# %%
df['İmtakeç']=df['Bal']>50
df
# Out:
#        Ad Cins  Bal  Yas  Status  İmtakeç
# 0  Bayram    K   67   18  Telebe     True
# 1  Maryam    Q   89   18  Telebe     True
# 2  Sevinc    Q   69   18  Telebe     True
# 3  Teymur    K   54   18  Telebe     True
# 4  Jasmin    Q   45   18  Telebe    False
# 5   Kamal    K   89   18  Telebe     True
# 6    Emil    K   78   18  Telebe     True

# %%
del df['İmtakeç']  # istediyimiz sütunu silmek üçün

# %%
df
# Out:
#        Ad Cins  Bal  Yas  Status
# 0  Bayram    K   67   18  Telebe
# 1  Maryam    Q   89   18  Telebe
# 2  Sevinc    Q   69   18  Telebe
# 3  Teymur    K   54   18  Telebe
# 4  Jasmin    Q   45   18  Telebe
# 5   Kamal    K   89   18  Telebe
# 6    Emil    K   78   18  Telebe

# %%
df.T #Setirle sütunun yerini deyişir.
# Out:
#              0       1       2       3       4       5       6
# Ad      Bayram  Maryam  Sevinc  Teymur  Jasmin   Kamal    Emil
# Cins         K       Q       Q       K       Q       K       K
# Bal         67      89      69      54      45      89      78
# Yas         18      18      18      18      18      18      18
# Status  Telebe  Telebe  Telebe  Telebe  Telebe  Telebe  Telebe

# %%
df[0:4]
# Out:
#        Ad Cins  Bal  Yas  Status
# 0  Bayram    K   67   18  Telebe
# 1  Maryam    Q   89   18  Telebe
# 2  Sevinc    Q   69   18  Telebe
# 3  Teymur    K   54   18  Telebe

# %%
df.drop('Yas',axis=1) #axis 1  sütun, axis 0  setir
#uzun müddetli silmek için df beraber edirik önüne onda tamamile silir
#inplace true ile df beraber etmemize gerek de qalmır.
# Out:
#        Ad Cins  Bal  Status
# 0  Bayram    K   67  Telebe
# 1  Maryam    Q   89  Telebe
# 2  Sevinc    Q   69  Telebe
# 3  Teymur    K   54  Telebe
# 4  Jasmin    Q   45  Telebe
# 5   Kamal    K   89  Telebe
# 6    Emil    K   78  Telebe

# %%
df
# Out:
#        Ad Cins  Bal  Yas  Status
# 0  Bayram    K   67   18  Telebe
# 1  Maryam    Q   89   18  Telebe
# 2  Sevinc    Q   69   18  Telebe
# 3  Teymur    K   54   18  Telebe
# 4  Jasmin    Q   45   18  Telebe
# 5   Kamal    K   89   18  Telebe
# 6    Emil    K   78   18  Telebe

# %%
df.drop(2,axis=0)
# Out:
#        Ad Cins  Bal  Yas  Status
# 0  Bayram    K   67   18  Telebe
# 1  Maryam    Q   89   18  Telebe
# 3  Teymur    K   54   18  Telebe
# 4  Jasmin    Q   45   18  Telebe
# 5   Kamal    K   89   18  Telebe
# 6    Emil    K   78   18  Telebe

# %%
df.sort_index(ascending=True)
# Out:
#        Ad Cins  Bal  Yas  Status
# 0  Bayram    K   67   18  Telebe
# 1  Maryam    Q   89   18  Telebe
# 2  Sevinc    Q   69   18  Telebe
# 3  Teymur    K   54   18  Telebe
# 4  Jasmin    Q   45   18  Telebe
# 5   Kamal    K   89   18  Telebe
# 6    Emil    K   78   18  Telebe

# %%
df.sort_index(axis=1)
# Out:
#        Ad  Bal Cins  Status  Yas
# 0  Bayram   67    K  Telebe   18
# 1  Maryam   89    Q  Telebe   18
# 2  Sevinc   69    Q  Telebe   18
# 3  Teymur   54    K  Telebe   18
# 4  Jasmin   45    Q  Telebe   18
# 5   Kamal   89    K  Telebe   18
# 6    Emil   78    K  Telebe   18

# %%
df.sort_values('Bal',ascending=False)
# Out:
#        Ad Cins  Bal  Yas  Status
# 1  Maryam    Q   89   18  Telebe
# 5   Kamal    K   89   18  Telebe
# 6    Emil    K   78   18  Telebe
# 2  Sevinc    Q   69   18  Telebe
# 0  Bayram    K   67   18  Telebe
# 3  Teymur    K   54   18  Telebe
# 4  Jasmin    Q   45   18  Telebe
